# %% [markdown]
# https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i

# %%
#!/usr/bin/env python

# make sure to install these packages before running:
# pip install pandas
# pip install sodapy

import pandas as pd
from sodapy import Socrata

# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofnewyork.us", app_token="e0tJs1ImNvkUMP9CVWSkaTcd7")

# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofnewyork.us,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
results = client.get("qgea-i56i",limit = 50000)

# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df.describe()
# Out:
#        cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm addr_pct_cd  \
# count       50000                    50000        50000       49992
# unique      50000                      672         1429          77
# top     394506329  2019-11-22T00:00:00.000     12:00:00          75
# freq            1                     1348         1263        1514
#
#                          rpt_dt  ky_cd      ofns_desc  pd_cd  \
# count                     50000  50000          49998  49892
# unique                      429     56             54    302
# top     2019-12-04T00:00:00.000    341  PETIT LARCENY  638.0
# freq                       1412  10633          10633   5601
#
#                       pd_desc crm_atpt_cptd_cd  ... cmplnt_to_tm  \
# count                   49892            50000  ...        43889
# unique                    270                2  ...         1435
# top     HARASSMENT,SUBD 3,4,5        COMPLETED  ...     12:00:00
# freq                     5606            49150  ...          669
#
#        loc_of_occur_desc susp_age_group susp_race susp_sex parks_nm  \
# count              41866          37945     37951    37950      223
# unique                 5              7         7        3       92
# top               INSIDE        UNKNOWN     BLACK        M       NA
# freq               28889          15863     14227    22533       31
#
#        housing_psa   hadevelopt transit_district station_name
# count         3490         2261             1356         1356
# unique         278          222               12          277
# top          887.0  CASTLE HILL              2.0   125 STREET
# freq            57           57              260           52
#
# [4 rows x 40 columns]

# %%
results_df
# Out:
#       cmplnt_num             cmplnt_fr_dt cmplnt_fr_tm addr_pct_cd  \
# 0      394506329  2019-12-31T00:00:00.000     17:30:00          32
# 1      968873685  2019-12-29T00:00:00.000     16:31:00          47
# 2      509837549  2019-12-15T00:00:00.000     18:45:00         109
# 3      352454313  2019-12-28T00:00:00.000     01:00:00          47
# 4      248803469  2008-09-05T00:00:00.000     21:41:00         NaN
# ...          ...                      ...          ...         ...
# 49995  891138821  2019-11-05T00:00:00.000     00:01:00          42
# 49996  490626669  2019-11-13T00:00:00.000     12:00:00          25
# 49997  577532290  2019-11-19T00:00:00.000     23:40:00          46
# 49998  109799275  2019-11-19T00:00:00.000     05:00:00          88
# 49999  644723280  2019-11-13T00:00:00.000     08:00:00          32
#
#                         rpt_dt ky_cd                        ofns_desc  pd_cd  \
# 0      2019-12-31T00:00:00.000   118                DANGEROUS WEAPONS  793.0
# 1      2019-12-29T00:00:00.000   113                          FORGERY  729.0
# 2      2019-12-29T00:00:00.000   578                    HARRASSMENT 2  638.0
# 3      2019-12-28T00:00:00.000   126          MISCELLANEOUS PENAL LAW  117.0
# 4      2008-09-05T00:00:00.000   101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# ...                        ...   ...                              ...    ...
# 49995  2019-11-15T00:00:00.000   341                    PETIT LARCENY  321.0
# 49996  2019-11-13T00:00:00.000   341                    PETIT LARCENY  338.0
# 49997  2019-11-20T00:00:00.000   578                    HARRASSMENT 2  637.0
# 49998  2019-11-21T00:00:00.000   113                          FORGERY  729.0
# 49999  2019-11-14T00:00:00.000   126          MISCELLANEOUS PENAL LAW  198.0
#
#                               pd_desc crm_atpt_cptd_cd  ... cmplnt_to_tm  \
# 0                WEAPONS POSSESSION 3        COMPLETED  ...          NaN
# 1      FORGERY,ETC.,UNCLASSIFIED-FELO        COMPLETED  ...     16:54:00
# 2               HARASSMENT,SUBD 3,4,5        COMPLETED  ...          NaN
# 3             RECKLESS ENDANGERMENT 1        COMPLETED  ...          NaN
# 4                                 NaN        COMPLETED  ...          NaN
# ...                               ...              ...  ...          ...
# 49995         LARCENY,PETIT FROM AUTO        COMPLETED  ...          NaN
# 49996  LARCENY,PETIT FROM BUILDING,UN        COMPLETED  ...     12:09:00
# 49997      HARASSMENT,SUBD 1,CIVILIAN        COMPLETED  ...     00:00:00
# 49998  FORGERY,ETC.,UNCLASSIFIED-FELO        COMPLETED  ...     05:20:00
# 49999             CRIMINAL CONTEMPT 1        COMPLETED  ...     03:29:00
#
#       loc_of_occur_desc susp_age_group       susp_race susp_sex parks_nm  \
# 0                   NaN            NaN             NaN      NaN      NaN
# 1                   NaN            NaN             NaN      NaN      NaN
# 2              FRONT OF          25-44         UNKNOWN        M      NaN
# 3               REAR OF          18-24           BLACK        M      NaN
# 4               OUTSIDE            NaN             NaN      NaN       NA
# ...                 ...            ...             ...      ...      ...
# 49995            INSIDE        UNKNOWN           BLACK        M      NaN
# 49996            INSIDE            NaN             NaN      NaN      NaN
# 49997            INSIDE          18-24           BLACK        F      NaN
# 49998            INSIDE        UNKNOWN           BLACK        F      NaN
# 49999            INSIDE          25-44  WHITE HISPANIC        M      NaN
#
#       housing_psa hadevelopt transit_district station_name
# 0             NaN        NaN              NaN          NaN
# 1             NaN        NaN              NaN          NaN
# 2             NaN        NaN              NaN          NaN
# 3             NaN        NaN              NaN          NaN
# 4              NA        NaN              NaN          NaN
# ...           ...        ...              ...          ...
# 49995         NaN        NaN              NaN          NaN
# 49996         NaN        NaN              NaN          NaN
# 49997         NaN        NaN              NaN          NaN
# 49998         NaN        NaN              NaN          NaN
# 49999       738.0     RANGEL              NaN          NaN
#
# [50000 rows x 40 columns]
